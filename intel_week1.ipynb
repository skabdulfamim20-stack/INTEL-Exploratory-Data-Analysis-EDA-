# %%
import pandas as pd
s=pd.Series([10,20,30,40,])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
marks=pd.Series([85,90,95], index=["Math","Science","English"])
print(marks)
# Out:
# Math       85
# Science    90
# English    95
# dtype: int64

# %%
import pandas as pd
data ={'Name':['Abdul','Famim'],'Age':[20,21]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Abdul   20
# 1  Famim   21

# %%
import pandas as pd
labels = ['a','b','c','d','e']
data =[12,45,67,89,23]
series = pd.Series(data, index=labels)
print(series['b'])
# Out:
# 45

# %%
import pandas as pd
data_dict = {'a':10,'b':20,'c':30}
series_from_dict = pd.Series(data_dict)
print(series_from_dict)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
import pandas as pd
data = {'Name':['Shaik','Abdul','Famim','sheikh','sohel','jani'], 'Age': [20,21,22,23,19,16]}
df = pd.DataFrame(data)
print(df.head)
print(df.tail)
# Out:
# <bound method NDFrame.head of      Name  Age
# 0   Shaik   20
# 1   Abdul   21
# 2   Famim   22
# 3  sheikh   23
# 4   sohel   19
# 5    jani   16>
# <bound method NDFrame.tail of      Name  Age
# 0   Shaik   20
# 1   Abdul   21
# 2   Famim   22
# 3  sheikh   23
# 4   sohel   19
# 5    jani   16>

# %%
import pandas as pd
data = {'Names':['shaik','Abdul','Famim','shaik','sohel'], 'Age':[20,21,22,19,20]}
df =pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Names   5 non-null      object
#  1   Age     5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes

# %%
import pandas as pd
data = {'Age':[20,21,22,23,24],'Salary':[40000,50000,60000,70000,80000]}
df = pd.DataFrame(data)
print(df.describe())
# Out:
#              Age        Salary
# count   5.000000      5.000000
# mean   22.000000  60000.000000
# std     1.581139  15811.388301
# min    20.000000  40000.000000
# 25%    21.000000  50000.000000
# 50%    22.000000  60000.000000
# 75%    23.000000  70000.000000
# max    24.000000  80000.000000
